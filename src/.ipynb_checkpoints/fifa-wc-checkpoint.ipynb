# %%
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
data = pd.read_csv("../dataset/matches.csv", header=0)

# %%
data.head(2)
# Out:
#      team1    team2 possession team1 possession team2 possession in contest  \
# 0    QATAR  ECUADOR              42%              50%                    8%
# 1  ENGLAND     IRAN              72%              19%                    9%
#
#    number of goals team1  number of goals team2          date     hour  \
# 0                      0                      2  20 nov. 2022  17 : 00
# 1                      6                      2  21 nov. 2022  14 : 00
#
#   category  total attempts team1  total attempts team2  conceded team1  \
# 0  Group A                     5                     6               2
# 1  Group B                    13                     8               2
#
#    conceded team2  goal inside the penalty area team1  \
# 0               0                                   0
# 1               6                                   6
#
#    goal inside the penalty area team2  goal outside the penalty area team1  \
# 0                                   2                                    0
# 1                                   2                                    0
#
#    goal outside the penalty area team2  assists team1  assists team2  \
# 0                                    0              0              1
# 1                                    0              6              1
#
#    on target attempts team1  on target attempts team2  \
# 0                         0                         3
# 1                         7                         3
#
#    off target attempts team1  off target attempts team2  \
# 0                          5                          3
# 1                          3                          4
#
#    attempts inside the penalty area team1  \
# 0                                       2
# 1                                      10
#
#    attempts inside the penalty area  team2  \
# 0                                        4
# 1                                        6
#
#    attempts outside the penalty area  team1  \
# 0                                         3
# 1                                         3
#
#    attempts outside the penalty area  team2  left channel team1  \
# 0                                         2                  15
# 1                                         2                  11
#
#    left channel team2  left inside channel team1  left inside channel team2  \
# 0                   8                          0                          7
# 1                   3                          5                          0
#
#    central channel team1  central channel team2  right inside channel team1  \
# 0                      3                      6                           1
# 1                      2                      3                           3
#
#    right inside channel team2  right channel team1  right channel team2  \
# 0                           4                    9                    6
# 1                           1                   11                    0
#
#    total offers to receive team1  total offers to receive team2  \
# 0                            520                            532
# 1                           1061                            212
#
#    inbehind offers to receive team1  inbehind offers to receive team2  \
# 0                               116                               127
# 1                               207                                53
#
#    inbetween offers to receive team1  inbetween offers to receive team2  \
# 0                                235                                187
# 1                                386                                 86
#
#    infront offers to receive team1  infront offers to receive team2  \
# 0                              169                              218
# 1                              468                               73
#
#    receptions between midfield and defensive lines team1  \
# 0                                                  5
# 1                                                 16
#
#    receptions between midfield and defensive lines team2  \
# 0                                                  8
# 1                                                  4
#
#    attempted line breaks team1  attempted line breaks team2  \
# 0                          136                          155
# 1                          238                          101
#
#    completed line breaksteam1  completed line breaks team2  \
# 0                          86                           99
# 1                         178                           45
#
#    attempted defensive line breaks team1  \
# 0                                      9
# 1                                     25
#
#    attempted defensive line breaks team2  \
# 0                                     13
# 1                                      7
#
#    completed defensive line breaks team1  \
# 0                                      4
# 1                                     16
#
#    completed defensive line breaks team2  yellow cards team1  \
# 0                                      7                   4
# 1                                      4                   0
#
#    yellow cards team2  red cards team1  red cards team2  fouls against team1  \
# 0                   2                0                0                   15
# 1                   2                0                0                    9
#
#    fouls against team2  offsides team1  offsides team2  passes team1  \
# 0                   15               3               4           450
# 1                   14               2               2           809
#
#    passes team2  passes completed team1  passes completed team2  \
# 0           480                     381                     409
# 1           224                     730                     154
#
#    crosses team1  crosses team2  crosses completed team1  \
# 0              9             14                        4
# 1             23              8                        7
#
#    crosses completed team2  switches of play completed team1  \
# 0                        4                                 9
# 1                        1                                12
#
#    switches of play completed team2  corners team1  corners team2  \
# 0                                 9              1              3
# 1                                 3              8              0
#
#    free kicks team1  free kicks team2  penalties scored team1  \
# 0                19                17                       0
# 1                16                10                       0
#
#    penalties scored team2  goal preventions team1  goal preventions team2  \
# 0                       1                       6                       5
# 1                       1                       8                      13
#
#    own goals team1  own goals team2  forced turnovers team1  \
# 0                0                0                      52
# 1                0                0                      63
#
#    forced turnovers team2  defensive pressures applied team1  \
# 0                      72                                256
# 1                      72                                139
#
#    defensive pressures applied team2
# 0                                279
# 1                                416

# %% [markdown]
# ### Renaming columns accordingly

# %%
def replace_spaces(s):
    return s.replace(" ", "_")

# %%
new_columns = {}
for col in data.columns:
    new_columns[col] = replace_spaces(col).upper()
    
data.rename(columns=new_columns).head()
# Out:
#            TEAM1         TEAM2 POSSESSION_TEAM1 POSSESSION_TEAM2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   POSSESSION_IN_CONTEST  NUMBER_OF_GOALS_TEAM1  NUMBER_OF_GOALS_TEAM2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#            DATE     HOUR CATEGORY  TOTAL_ATTEMPTS_TEAM1  TOTAL_ATTEMPTS_TEAM2  \
# 0  20 nov. 2022  17 : 00  Group A                     5                     6
# 1  21 nov. 2022  14 : 00  Group B                    13                     8
# 2  21 nov. 2022  17 : 00  Group A                    14                     9
# 3  21 nov. 2022  20 : 00  Group B                     6                     7
# 4  22 nov. 2022  11 : 00  Group C                    14                     3
#
#    CONCEDED_TEAM1  CONCEDED_TEAM2  GOAL_INSIDE_THE_PENALTY_AREA_TEAM1  \
# 0               2               0                                   0
# 1               2               6                                   6
# 2               2               0                                   0
# 3               1               1                                   1
# 4               2               1                                   1
#
#    GOAL_INSIDE_THE_PENALTY_AREA_TEAM2  GOAL_OUTSIDE_THE_PENALTY_AREA_TEAM1  \
# 0                                   2                                    0
# 1                                   2                                    0
# 2                                   2                                    0
# 3                                   1                                    0
# 4                                   2                                    0
#
#    GOAL_OUTSIDE_THE_PENALTY_AREA_TEAM2  ASSISTS_TEAM1  ASSISTS_TEAM2  \
# 0                                    0              0              1
# 1                                    0              6              1
# 2                                    0              0              1
# 3                                    0              1              0
# 4                                    0              0              1
#
#    ON_TARGET_ATTEMPTS_TEAM1  ON_TARGET_ATTEMPTS_TEAM2  \
# 0                         0                         3
# 1                         7                         3
# 2                         3                         3
# 3                         1                         3
# 4                         6                         2
#
#    OFF_TARGET_ATTEMPTS_TEAM1  OFF_TARGET_ATTEMPTS_TEAM2  \
# 0                          5                          3
# 1                          3                          4
# 2                          8                          5
# 3                          4                          3
# 4                          5                          0
#
#    ATTEMPTS_INSIDE_THE_PENALTY_AREA_TEAM1  \
# 0                                       2
# 1                                      10
# 2                                       7
# 3                                       4
# 4                                      10
#
#    ATTEMPTS_INSIDE_THE_PENALTY_AREA__TEAM2  \
# 0                                        4
# 1                                        6
# 2                                        5
# 3                                        5
# 4                                        3
#
#    ATTEMPTS_OUTSIDE_THE_PENALTY_AREA__TEAM1  \
# 0                                         3
# 1                                         3
# 2                                         7
# 3                                         2
# 4                                         4
#
#    ATTEMPTS_OUTSIDE_THE_PENALTY_AREA__TEAM2  LEFT_CHANNEL_TEAM1  \
# 0                                         2                  15
# 1                                         2                  11
# 2                                         4                  12
# 3                                         2                  14
# 4                                         0                  12
#
#    LEFT_CHANNEL_TEAM2  LEFT_INSIDE_CHANNEL_TEAM1  LEFT_INSIDE_CHANNEL_TEAM2  \
# 0                   8                          0                          7
# 1                   3                          5                          0
# 2                  11                          4                          2
# 3                   7                          5                          2
# 4                   3                          4                          2
#
#    CENTRAL_CHANNEL_TEAM1  CENTRAL_CHANNEL_TEAM2  RIGHT_INSIDE_CHANNEL_TEAM1  \
# 0                      3                      6                           1
# 1                      2                      3                           3
# 2                      2                      2                           4
# 3                      4                      5                           4
# 4                      5                      3                           8
#
#    RIGHT_INSIDE_CHANNEL_TEAM2  RIGHT_CHANNEL_TEAM1  RIGHT_CHANNEL_TEAM2  \
# 0                           4                    9                    6
# 1                           1                   11                    0
# 2                           7                   13                   20
# 3                           2                   11                    7
# 4                           3                   18                    8
#
#    TOTAL_OFFERS_TO_RECEIVE_TEAM1  TOTAL_OFFERS_TO_RECEIVE_TEAM2  \
# 0                            520                            532
# 1                           1061                            212
# 2                            502                            506
# 3                            725                            436
# 4                            650                            268
#
#    INBEHIND_OFFERS_TO_RECEIVE_TEAM1  INBEHIND_OFFERS_TO_RECEIVE_TEAM2  \
# 0                               116                               127
# 1                               207                                53
# 2                               123                               117
# 3                               149                               100
# 4                               157                                69
#
#    INBETWEEN_OFFERS_TO_RECEIVE_TEAM1  INBETWEEN_OFFERS_TO_RECEIVE_TEAM2  \
# 0                                235                                187
# 1                                386                                 86
# 2                                230                                191
# 3                                336                                172
# 4                                177                                131
#
#    INFRONT_OFFERS_TO_RECEIVE_TEAM1  INFRONT_OFFERS_TO_RECEIVE_TEAM2  \
# 0                              169                              218
# 1                              468                               73
# 2                              149                              198
# 3                              240                              164
# 4                              316                               68
#
#    RECEPTIONS_BETWEEN_MIDFIELD_AND_DEFENSIVE_LINES_TEAM1  \
# 0                                                  5
# 1                                                 16
# 2                                                 15
# 3                                                 12
# 4                                                 26
#
#    RECEPTIONS_BETWEEN_MIDFIELD_AND_DEFENSIVE_LINES_TEAM2  \
# 0                                                  8
# 1                                                  4
# 2                                                 14
# 3                                                  9
# 4                                                  9
#
#    ATTEMPTED_LINE_BREAKS_TEAM1  ATTEMPTED_LINE_BREAKS_TEAM2  \
# 0                          136                          155
# 1                          238                          101
# 2                          151                          162
# 3                          199                          174
# 4                          191                          137
#
#    COMPLETED_LINE_BREAKSTEAM1  COMPLETED_LINE_BREAKS_TEAM2  \
# 0                          86                           99
# 1                         178                           45
# 2                          89                           96
# 3                         146                          103
# 4                         127                           68
#
#    ATTEMPTED_DEFENSIVE_LINE_BREAKS_TEAM1  \
# 0                                      9
# 1                                     25
# 2                                     22
# 3                                     23
# 4                                     39
#
#    ATTEMPTED_DEFENSIVE_LINE_BREAKS_TEAM2  \
# 0                                     13
# 1                                      7
# 2                                     22
# 3                                     17
# 4                                     15
#
#    COMPLETED_DEFENSIVE_LINE_BREAKS_TEAM1  \
# 0                                      4
# 1                                     16
# 2                                     15
# 3                                     15
# 4                                     25
#
#    COMPLETED_DEFENSIVE_LINE_BREAKS_TEAM2  YELLOW_CARDS_TEAM1  \
# 0                                      7                   4
# 1                                      4                   0
# 2                                     10                   2
# 3                                      8                   4
# 4                                      7                   0
#
#    YELLOW_CARDS_TEAM2  RED_CARDS_TEAM1  RED_CARDS_TEAM2  FOULS_AGAINST_TEAM1  \
# 0                   2                0                0                   15
# 1                   2                0                0                    9
# 2                   1                0                0                   13
# 3                   2                0                0                   15
# 4                   6                0                0                    7
#
#    FOULS_AGAINST_TEAM2  OFFSIDES_TEAM1  OFFSIDES_TEAM2  PASSES_TEAM1  \
# 0                   15               3               4           450
# 1                   14               2               2           809
# 2                   13               2               1           383
# 3                   10               1               1           569
# 4                   21              10               1           610
#
#    PASSES_TEAM2  PASSES_COMPLETED_TEAM1  PASSES_COMPLETED_TEAM2  \
# 0           480                     381                     409
# 1           224                     730                     154
# 2           438                     313                     374
# 3           409                     509                     321
# 4           267                     529                     190
#
#    CROSSES_TEAM1  CROSSES_TEAM2  CROSSES_COMPLETED_TEAM1  \
# 0              9             14                        4
# 1             23              8                        7
# 2             19             25                        7
# 3             31             15                        4
# 4             29              9                       12
#
#    CROSSES_COMPLETED_TEAM2  SWITCHES_OF_PLAY_COMPLETED_TEAM1  \
# 0                        4                                 9
# 1                        1                                12
# 2                        8                                 9
# 3                        6                                 5
# 4                        2                                 5
#
#    SWITCHES_OF_PLAY_COMPLETED_TEAM2  CORNERS_TEAM1  CORNERS_TEAM2  \
# 0                                 9              1              3
# 1                                 3              8              0
# 2                                 6              6              7
# 3                                 8              5              3
# 4                                 7              9              2
#
#    FREE_KICKS_TEAM1  FREE_KICKS_TEAM2  PENALTIES_SCORED_TEAM1  \
# 0                19                17                       0
# 1                16                10                       0
# 2                14                14                       0
# 3                11                15                       0
# 4                22                16                       1
#
#    PENALTIES_SCORED_TEAM2  GOAL_PREVENTIONS_TEAM1  GOAL_PREVENTIONS_TEAM2  \
# 0                       1                       6                       5
# 1                       1                       8                      13
# 2                       0                       9                      15
# 3                       1                       7                       7
# 4                       0                       4                      14
#
#    OWN_GOALS_TEAM1  OWN_GOALS_TEAM2  FORCED_TURNOVERS_TEAM1  \
# 0                0                0                      52
# 1                0                0                      63
# 2                0                0                      63
# 3                0                0                      81
# 4                0                0                      65
#
#    FORCED_TURNOVERS_TEAM2  DEFENSIVE_PRESSURES_APPLIED_TEAM1  \
# 0                      72                                256
# 1                      72                                139
# 2                      73                                263
# 3                      72                                242
# 4                      80                                163
#
#    DEFENSIVE_PRESSURES_APPLIED_TEAM2
# 0                                279
# 1                                416
# 2                                251
# 3                                292
# 4                                361

# %%
data.DATE = data.DATE.str.replace('nov.', '11', regex=False)
data.DATE = data.DATE.str.replace('DEC', '12', regex=False)
data.DATE = data.DATE.str.replace(' ', '', regex=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[306], line 1
# ----> 1 data.DATE = data.DATE.str.replace('nov.', '11', regex=False)
#       2 data.DATE = data.DATE.str.replace('DEC', '12', regex=False)
#       3 data.DATE = data.DATE.str.replace(' ', '', regex=False)
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DATE'

# %%
data.DATE = pd.to_datetime(data.DATE, format='%d%m%Y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[300], line 1
# ----> 1 data.DATE = pd.to_datetime(data.DATE, format='%d%m%Y')
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DATE'

# %%
argentina_home = data.loc[data.TEAM1 == 'ARGENTINA']
argentina_visitant = data.loc[data.TEAM2 == 'ARGENTINA']
argentina = pd.concat([argentina_home, argentina_visitant], axis=0)

# %%
argentina.sort_values(by='DATE', ascending=True)
# Out:
#           TEAM1         TEAM2 POSSESSION_TEAM1 POSSESSION_TEAM2  \
# 4     ARGENTINA  SAUDI ARABIA              64%              24%
# 23    ARGENTINA        MEXICO              50%              36%
# 38       POLAND     ARGENTINA              24%              67%
# 49    ARGENTINA     AUSTRALIA              53%              35%
# 57  NETHERLANDS     ARGENTINA              45%              44%
# 60    ARGENTINA       CROATIA              34%              54%
# 63    ARGENTINA        FRANCE              46%              40%
#
#    POSSESSION_IN_CONTEST  NUMBER_OF_GOALS_TEAM1  NUMBER_OF_GOALS_TEAM2  \
# 4                    12%                      1                      2
# 23                   14%                      2                      0
# 38                    9%                      0                      2
# 49                   12%                      2                      1
# 57                   11%                      2                      2
# 60                   12%                      3                      0
# 63                   14%                      3                      3
#
#          DATE     HOUR       CATEGORY  TOTAL_ATTEMPTS_TEAM1  \
# 4  2022-11-22  11 : 00        Group C                    14
# 23 2022-11-26  20 : 00        Group C                     5
# 38 2022-11-30  20 : 00        Group C                     4
# 49 2022-12-03  20 : 00    Round of 16                    14
# 57 2022-12-09  20 : 00  Quarter-final                     5
# 60 2022-12-13  20 : 00     Semi-final                    10
# 63 2022-12-18  16 : 00          Final                    21
#
#     TOTAL_ATTEMPTS_TEAM2  CONCEDED_TEAM1  CONCEDED_TEAM2  \
# 4                      3               2               1
# 23                     4               0               2
# 38                    25               2               0
# 49                     5               1               2
# 57                    15               2               2
# 60                    12               0               3
# 63                    10               3               3
#
#     GOAL_INSIDE_THE_PENALTY_AREA_TEAM1  GOAL_INSIDE_THE_PENALTY_AREA_TEAM2  \
# 4                                    1                                   2
# 23                                   1                                   0
# 38                                   0                                   2
# 49                                   2                                   0
# 57                                   2                                   2
# 60                                   3                                   0
# 63                                   3                                   3
#
#     GOAL_OUTSIDE_THE_PENALTY_AREA_TEAM1  GOAL_OUTSIDE_THE_PENALTY_AREA_TEAM2  \
# 4                                     0                                    0
# 23                                    1                                    0
# 38                                    0                                    0
# 49                                    0                                    0
# 57                                    0                                    0
# 60                                    0                                    0
# 63                                    0                                    0
#
#     ASSISTS_TEAM1  ASSISTS_TEAM2  ON_TARGET_ATTEMPTS_TEAM1  \
# 4               0              1                         6
# 23              2              0                         2
# 38              0              2                         0
# 49              1              0                         5
# 57              2              1                         2
# 60              1              0                         7
# 63              1              1                         9
#
#     ON_TARGET_ATTEMPTS_TEAM2  OFF_TARGET_ATTEMPTS_TEAM1  \
# 4                          2                          5
# 23                         1                          3
# 38                        13                          2
# 49                         2                          7
# 57                         6                          2
# 60                         3                          2
# 63                         5                          9
#
#     OFF_TARGET_ATTEMPTS_TEAM2  ATTEMPTS_INSIDE_THE_PENALTY_AREA_TEAM1  \
# 4                           0                                      10
# 23                          2                                       2
# 38                          8                                       2
# 49                          2                                      11
# 57                          8                                       3
# 60                          7                                       7
# 63                          3                                      10
#
#     ATTEMPTS_INSIDE_THE_PENALTY_AREA__TEAM2  \
# 4                                         3
# 23                                        1
# 38                                       21
# 49                                        3
# 57                                        5
# 60                                        6
# 63                                        7
#
#     ATTEMPTS_OUTSIDE_THE_PENALTY_AREA__TEAM1  \
# 4                                          4
# 23                                         3
# 38                                         2
# 49                                         3
# 57                                         2
# 60                                         3
# 63                                        11
#
#     ATTEMPTS_OUTSIDE_THE_PENALTY_AREA__TEAM2  LEFT_CHANNEL_TEAM1  \
# 4                                          0                  12
# 23                                         3                  10
# 38                                         4                   6
# 49                                         2                  15
# 57                                        10                  11
# 60                                         6                   8
# 63                                         3                  13
#
#     LEFT_CHANNEL_TEAM2  LEFT_INSIDE_CHANNEL_TEAM1  LEFT_INSIDE_CHANNEL_TEAM2  \
# 4                    3                          4                          2
# 23                   8                          6                          1
# 38                  25                          2                          8
# 49                   8                          6                          1
# 57                   7                          7                          7
# 60                  18                          9                          6
# 63                  15                          6                          7
#
#     CENTRAL_CHANNEL_TEAM1  CENTRAL_CHANNEL_TEAM2  RIGHT_INSIDE_CHANNEL_TEAM1  \
# 4                       5                      3                           8
# 23                      2                      1                           4
# 38                      1                      7                           2
# 49                     11                      2                           2
# 57                      9                     13                           3
# 60                      7                      7                           3
# 63                      8                      5                           9
#
#     RIGHT_INSIDE_CHANNEL_TEAM2  RIGHT_CHANNEL_TEAM1  RIGHT_CHANNEL_TEAM2  \
# 4                            3                   18                    8
# 23                           2                   12                   11
# 38                          10                    3                   26
# 49                           6                   17                    9
# 57                           6                   15                   17
# 60                           4                    2                    8
# 63                           4                    9                   12
#
#     TOTAL_OFFERS_TO_RECEIVE_TEAM1  TOTAL_OFFERS_TO_RECEIVE_TEAM2  \
# 4                             650                            268
# 23                            569                            373
# 38                            328                            907
# 49                            869                            538
# 57                            722                            644
# 60                            349                            643
# 63                            607                            507
#
#     INBEHIND_OFFERS_TO_RECEIVE_TEAM1  INBEHIND_OFFERS_TO_RECEIVE_TEAM2  \
# 4                                157                                69
# 23                               103                                78
# 38                                62                               175
# 49                               131                               105
# 57                               117                                97
# 60                                89                               136
# 63                               146                               105
#
#     INBETWEEN_OFFERS_TO_RECEIVE_TEAM1  INBETWEEN_OFFERS_TO_RECEIVE_TEAM2  \
# 4                                 177                                131
# 23                                244                                151
# 38                                126                                282
# 49                                337                                184
# 57                                278                                278
# 60                                122                                291
# 63                                257                                207
#
#     INFRONT_OFFERS_TO_RECEIVE_TEAM1  INFRONT_OFFERS_TO_RECEIVE_TEAM2  \
# 4                               316                               68
# 23                              222                              144
# 38                              140                              450
# 49                              401                              249
# 57                              327                              269
# 60                              138                              216
# 63                              204                              195
#
#     RECEPTIONS_BETWEEN_MIDFIELD_AND_DEFENSIVE_LINES_TEAM1  \
# 4                                                  26
# 23                                                  2
# 38                                                  2
# 49                                                  8
# 57                                                  5
# 60                                                  7
# 63                                                 43
#
#     RECEPTIONS_BETWEEN_MIDFIELD_AND_DEFENSIVE_LINES_TEAM2  \
# 4                                                   9
# 23                                                  5
# 38                                                 21
# 49                                                  8
# 57                                                  7
# 60                                                  3
# 63                                                 10
#
#     ATTEMPTED_LINE_BREAKS_TEAM1  ATTEMPTED_LINE_BREAKS_TEAM2  \
# 4                           191                          137
# 23                          150                          127
# 38                          117                          214
# 49                          181                          146
# 57                          194                          203
# 60                          147                          182
# 63                          223                          163
#
#     COMPLETED_LINE_BREAKSTEAM1  COMPLETED_LINE_BREAKS_TEAM2  \
# 4                          127                           68
# 23                         100                           66
# 38                          66                          188
# 49                         135                           92
# 57                         130                          122
# 60                          91                          129
# 63                         151                           99
#
#     ATTEMPTED_DEFENSIVE_LINE_BREAKS_TEAM1  \
# 4                                      39
# 23                                     10
# 38                                      5
# 49                                     16
# 57                                     15
# 60                                     17
# 63                                     38
#
#     ATTEMPTED_DEFENSIVE_LINE_BREAKS_TEAM2  \
# 4                                      15
# 23                                     13
# 38                                     25
# 49                                     12
# 57                                     24
# 60                                      9
# 63                                     14
#
#     COMPLETED_DEFENSIVE_LINE_BREAKS_TEAM1  \
# 4                                      25
# 23                                      5
# 38                                      1
# 49                                      8
# 57                                      6
# 60                                      7
# 63                                     23
#
#     COMPLETED_DEFENSIVE_LINE_BREAKS_TEAM2  YELLOW_CARDS_TEAM1  \
# 4                                       7                   0
# 23                                      5                   1
# 38                                     19                   1
# 49                                      7                   0
# 57                                      8                   8
# 60                                      1                   2
# 63                                      9                   4
#
#     YELLOW_CARDS_TEAM2  RED_CARDS_TEAM1  RED_CARDS_TEAM2  FOULS_AGAINST_TEAM1  \
# 4                    6                0                0                    7
# 23                   4                0                0                   15
# 38                   1                0                0                    6
# 49                   2                0                0                    8
# 57                   8                1                0                   30
# 60                   2                0                0                   15
# 63                   3                0                0                   26
#
#     FOULS_AGAINST_TEAM2  OFFSIDES_TEAM1  OFFSIDES_TEAM2  PASSES_TEAM1  \
# 4                    21              10               1           610
# 23                   19               2               4           533
# 38                   11               0               0           321
# 49                   15               4               0           711
# 57                   18               1               2           651
# 60                    8               1               0           408
# 63                   19               4               4           648
#
#     PASSES_TEAM2  PASSES_COMPLETED_TEAM1  PASSES_COMPLETED_TEAM2  \
# 4            267                     529                     190
# 23           356                     464                     287
# 38           862                     261                     814
# 49           450                     635                     381
# 57           603                     557                     511
# 60           624                     344                     551
# 63           516                     544                     419
#
#     CROSSES_TEAM1  CROSSES_TEAM2  CROSSES_COMPLETED_TEAM1  \
# 4              29              9                       12
# 23             14             17                        2
# 38              5             22                        2
# 49              6             15                        1
# 57             22             16                        4
# 60              8             20                        2
# 63             20             24                        4
#
#     CROSSES_COMPLETED_TEAM2  SWITCHES_OF_PLAY_COMPLETED_TEAM1  \
# 4                         2                                 5
# 23                        4                                 3
# 38                        5                                 8
# 49                        2                                 5
# 57                        4                                 5
# 60                        4                                 4
# 63                        3                                 6
#
#     SWITCHES_OF_PLAY_COMPLETED_TEAM2  CORNERS_TEAM1  CORNERS_TEAM2  \
# 4                                  7              9              2
# 23                                 2              4              2
# 38                                11              1              9
# 49                                 8              1              3
# 57                                 4              2              8
# 60                                 8              2              4
# 63                                 5              6              5
#
#     FREE_KICKS_TEAM1  FREE_KICKS_TEAM2  PENALTIES_SCORED_TEAM1  \
# 4                 22                16                       1
# 23                23                17                       0
# 38                12                 5                       0
# 49                15                11                       0
# 57                20                30                       0
# 60                 6                16                       1
# 63                22                28                       1
#
#     PENALTIES_SCORED_TEAM2  GOAL_PREVENTIONS_TEAM1  GOAL_PREVENTIONS_TEAM2  \
# 4                        0                       4                      14
# 23                       0                       4                       5
# 38                       0                      25                       4
# 49                       0                       5                      14
# 57                       1                      15                       5
# 60                       0                      12                      10
# 63                       2                      11                      21
#
#     OWN_GOALS_TEAM1  OWN_GOALS_TEAM2  FORCED_TURNOVERS_TEAM1  \
# 4                 0                0                      65
# 23                0                0                      63
# 38                0                0                      67
# 49                1                0                      67
# 57                0                0                      91
# 60                0                0                      85
# 63                0                0                      87
#
#     FORCED_TURNOVERS_TEAM2  DEFENSIVE_PRESSURES_APPLIED_TEAM1  \
# 4                       80                                163
# 23                      79                                220
# 38                      48                                438
# 49                      73                                240
# 57                      79                                401
# 60                      63                                321
# 63                     104                                280
#
#     DEFENSIVE_PRESSURES_APPLIED_TEAM2
# 4                                 361
# 23                                327
# 38                                141
# 49                                453
# 57                                323
# 60                                260
# 63                                409

# %% [markdown]
# ### Greater ball possession against the only team to whom they lost

# %%
argentina_home = argentina.loc[argentina.TEAM1 == 'ARGENTINA', :]
argentina_home.POSSESSION_TEAM1 = argentina_home.POSSESSION_TEAM1.str.replace('%', '').astype(int)
argentina_home = pd.concat([argentina_home.TEAM2, argentina_home.POSSESSION_TEAM1, argentina_home.DATE], axis=1)
argentina_home = argentina_home.rename(columns={'TEAM2': 'OPONENT', 'POSSESSION_TEAM1': 'POSSESSION'})

argentina_away = argentina.loc[argentina.TEAM2 == 'ARGENTINA', :]
argentina_away.POSSESSION_TEAM2 = argentina_away.POSSESSION_TEAM2.str.replace('%', '').astype(int)
argentina_away = pd.concat([argentina_away.TEAM1, argentina_away.POSSESSION_TEAM2, argentina_away.DATE], axis=1)
argentina_away = argentina_away.rename(columns={'TEAM1': 'OPONENT', 'POSSESSION_TEAM2': 'POSSESSION'})

data = pd.concat([argentina_home, argentina_away], axis=0).sort_values(by='DATE', ascending=True)

plot = sns.catplot(data=data, kind='bar', x='OPONENT', y='POSSESSION', aspect=1.8, height=4, palette='dark', alpha=.8)
plot.despine(left=True)
plot.set_axis_labels("OPONENTS", "ARGENTINA BALL POSSESSION (%)")
